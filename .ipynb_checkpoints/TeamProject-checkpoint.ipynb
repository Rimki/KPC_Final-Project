# %%
# import
from bs4 import BeautifulSoup as bs
import requests
import numpy as np
import pandas as pd
import re

import time

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.wait import WebDriverWait

# %%
# 해당 페이지 설정
browser = webdriver.Chrome(executable_path="C:\\chromedriver_win32\\chromedriver.exe")

browser.get("https://linkareer.com/cover-letter/24360?page=1&sort=SCRAP_COUNT&tab=all")

# %%
soup.find_all("p")[1].text
# Out:
# '인천국제공항공사 / 기계 / 2019 하반기'

# %%
soup.find_all("p")[2].text
# Out:
# '영남대학교 / 학점 3.83 / 일반기계기사 / 자동차정비기능사/ 토익 850 / 토스 lv6 150점 / 한국사 1급 / 학내 봉사동아리'

# %%
soup.find_all("p")[5].text
# Out:
# '1. 본인이 알고 있는 인천국제공항공사에 대한 내용(대내외 환경, 조직특성, 주요사업 등)은 무엇이며, 그 정보를 어떻게 얻게 되었는지 기술해 주십시오. \n또한, 그 중 어떠한 점에 이끌려 우리공사에 지원하게 되었는지 기술해 주십시오. \n[ 100자 이상 600자 이내 ]  글자수자\n\n여행을 좋아하기 때문에 아르바이트하며 모은 돈으로 방학 때마다 여행을 다닙니다. 작년 여름 해외에 가기 위해 인천국제공항에 가서 길을 잃은 적이 있습니다. 그만큼 타 공항과는 비교도 안 될 만큼의 규모와 시설들을 보고 감탄했습니다. 그 후 인천국제공항공사에 대해 매료되었고 인터넷을 통해 관련된 다양한 정보들을 얻을 수 있었습니다.\n\n인천국제공항공사는 대한민국을 대표하며 개설 이후부터 24시간 무중단으로 무사고를 달성했다는 것을 보며 기본적인 시설 관리뿐만 아니라 지상, 비행장시설 전체 부분에 대해 체계적인 안전관리시스템 및 노하우를 확인할 수 있었습니다. 이를 토대로 2009년 이라크 아르빌 신공항부터 14개국에 다양한 운영컨설팅 사업을 추진하며 세계적인 위상을 돋보이고 있는 것을 확인할 수 있었습니다. 또한, ‘공항’이라는 단순한 항공기의 공간이 아닌 다양한 산업으로 높은 부가가치를 창출하는 거대한 산업이라는 것으로 인지하여 공항복합도시 개발에도 만전을 가하고 있습니다. \n이렇듯, 전 세계를 선도하고 있는 인천국제공항공사에서 근무하여 기계의 품질관리와 장비에 대한 정비를 꼼꼼히 하며 많은 여행객이 차질 없이 다닐 수 있도록 기여하고 싶습니다.\n\n2. 우리공사에 지원하는 분야 및 우리공사 인재상과 관련하여 당신은 어떤 면에서 준비가 되어 있으며, 최근 3년 이내에 해당 능력을 개발하기 위해 어떠한 노력을 기울였는지 구체적인 사례로 기술해 주시고, 입사 후의 계획 및 포부에 대하여 기술해 주십시오. \n[ 100자 이상 600자 이내 ] 글자수자\n\n군 복학 후 학과 공부에 흥미도 붙이지 못해 자신도 없어 미래에 갈팡질팡했습니다. 하지만 설날에 큰아버지께서 같은 기계공학도로서의 장점을 말씀해주시는 모습에 저는 ‘최선을 다해보자’고 결심했습니다.\n\n그때부터 낮은 학점과 부족했던 전공지식에도 불구하고 ‘과 수석’을 할 것이라는 마음으로 공부에 임했습니다. 연계과목들이 많아 부족했던 지식을 메꿔야 해서 많은 시간 투자가 필요했습니다. 아르바이트도 병행했기에 시간 관리의 중요성을 느끼며 철저히 계획을 세워 실행해 나갔습니다.\n정말 열심히 한 결과, 그전보다 훨씬 우수한 성적을 취득할 수 있었고, 저의 역량 개발에 많은 도움이 되었습니다. \n\n이를 통해 저 자신의 도전역량을 알 수 있었고, 끝까지 포기하지 않는 사람이라는 것을 발견했습니다. 이처럼 학과에서 최선을 다했던 지난 2년의 세월이 저에게는 기계공학도로서의 미래를 이어갈 수 있는 발판이 되었습니다.\n\n발전해나가고자 하는 저에게 궁극적으로 회사는 꿈을 이룰 수 있는 곳이기에, 발전된 미래를 함께할 수 있는지는 상당히 중요하다고 생각합니다. 학부에서의 다방면의 전문지식과 설계경험은 인천국제공항공사에서 장비 유지보수 및 관리를 위한 시작이 될 것입니다.\n\n\n3. 본인의 장점에 대해 기술하고 그 장점을 발휘하여 성공적으로 일을 처리한 경험, 또는 새로운 문제에 대해 기존에 없던 혹은 이전과 다른 방식으로 문제를 \n해결했던 경험을 구체적인 사례로 기술해 주시고, 이러한 경험이 우리공사에 어떠한 기여를 할 수 있을지에 대해 기술해 주십시오. \n[ 100자 이상 600자 이내 ] 글자수자\n\n제가 가지고 있는 차별화된 장점은 ‘긍정’의 마음입니다.\n\n"날개 없는 IOT 선풍기"를 주제로 한 Capston Design을 진행한 경험이 있습니다.\n처음엔 소비자의 니즈를 파악하고 노즐, 임펠러, 모터 속도, 외관 등을 설계변수로 정하였습니다. 또한, 가격이 저렴한 중국 제품을 역설계 해보았고 그 후 외형, 유체해석, 기능 면을 각각 CATIA, ANSYS, IOT로 팀을 꾸려 진행하였습니다. \n제가 속한 IOT팀에서는 모터의 속도 및 회전 제어, 온습도 센서, LCD 기판 탑재, 원격제어를 알고리즘을 통해 구현해야 했습니다. 많은 부품이 들어가기에 정교한 알고리즘을 세우는 것이 매우 중요했지만, 전공 특성상 능력이 많이 부족하여 많은 시행착오로 좌절하여 모두 포기 직전까지 갔습니다. 그러나 저는 포기하지 않고 미리 준비한 계획들을 알려주며 먼저 사기를 북돋울 수 있도록 노력했습니다. 저의 열심히 하는 모습에 팀원들은 다시 진지하게 프로젝트에 임할 수 있었습니다. \n결과적으로 구현에 성공하였고, 이 과제에서 저의 매사에 성공할 것이라는 믿음으로 도전하는 긍정의 마음이 팀원에게 잘 전달되어 프로젝트를 원활히 수행할 수 있었던 것 같습니다.\n\n\n4. 본인이 어떤 단체(조직, 동아리 등)에 소속되어 공동과업을 달성하는 과정에서 구성원들과 관계에서 발생했던 어려움은 무엇이었으며, 그 어려움을 극복하기 \n위해 어떠한 노력을 기울였는지 구체적인 사례로 기술해 주십시오. \n\n[ 100자 이상 600자 이내 ] 글자수자\n\n대학교에서 봉사 활동하며 다양한 사람들과 친목활동의 시간은 다소 지쳐있던 삶에 큰 활력이었습니다. 하지만 단순히 졸업을 위한 봉사활동을 채우기 위해 들어와 시간만 채우고 금방 나가는 경우가 많았습니다.\n\n제대 후 복학하여 동아리 회장으로 활동하며 이런 문제 개선을 위한 방법을 고민했습니다. 하지만 2년이라는 긴 세월 동안 많은 인원이 교체되어 처음 본 사람들이 대부분이었습니다. 혼자 들어온 후배뿐만 아니라 봉사활동만 하고 나가려는 사람들은 먼저 다가가는 데 익숙하지 않은 성격이라고 생각했고, 저보다는 구성원들끼리 먼저 친해지는 것이 우선적이라고 생각했습니다.\n그래서 서로에게 친해질 기회를 만들 저는 ‘마니토’를 해보자고 추진했습니다. ‘마니토’는 추첨을 통해 자신의 정체를 숨기고 편지나 선물을 제공하는 사람입니다. 이것은 모두의 참여가 중요한데 구성원들이 많은 참여를 하지 않을 것이라는 반대에 부딪혔지만, 흐지부지될 뻔했던 것을 수차례에 걸친 회장단과의 논의를 바탕으로 구체적인 계획을 세워 추진해나갔습니다. 처음엔 모두 어리둥절했지만, 진정성이 통하였는지 결국엔 모두가 재밌어했고 친해질 수 있었습니다.\n\n\n\n\n\n\n5. 본인이 최근 3년간 타인을 위하여 어떠한 희생과 봉사의 노력을 기울여 왔으며, 그중 특별히 인상 깊은 활동 사례는 무엇이고 본인은 그 활동에서 어떤 역할을 하였는지에 대하여 구체적으로 기술해 주십시오.\n(입사지원서에 입력한 「사회봉사 활동내역」을 중심으로 작성) \n[ 100자 이상 600자 이내 ] 글자수자\n\n저희 동아리가 봉사활동 가는 곳은 장애 영아원으로, 몸이 불편하거나 정신지체를 가지고 있는 어린아이들과 놀아주며 생활에 편의를 지원해주는 봉사활동을 합니다. 아이들을 처음 봤을 때는 두렵기도 하고 불편해서 어찌할지를 몰랐습니다.\n\n군 제대 후 동아리 회장을 하면서 봉사활동을 계획하고 사람들을 이끌어야 했습니다. 회장으로서 임무를 위해 봉사활동을 하러 갔는데, 놀랍게도 2년 전 그 아이들이 저를 기억하고 있었습니다. 심지어 제 이름을 부르는 아이도 있었으며 모두 반갑게 반겨주었습니다. 그 순간 저 자신이 너무 창피하였습니다. 저는 아이들을 꺼리고 피했는데 아이들은 장애가 있고 한참 어린데도 먼저 마음을 열어준 것입니다. 그 후로 저도 아이들에게 마음을 열고 진심으로 대하여 저희는 가까워졌습니다. 그 후 개인적으로 매달 한 번씩 정기 봉사활동을 하고 있으며, 방학 때는 캠프도 가서 재미있는 추억을 만들었습니다.\n\n봉사뿐 만 아니라 사람 사이의 관계에서 상대방의 마음을 얻기 위해서는 자신이 먼저 마음을 열고 진심으로 대하여 한다는 것을 알았습니다. 저는 이 교훈을 얻고 사람을 대할 때 거짓과 가식이 없이 항상 진심으로 대하고 먼저 다가가기 위해 노력하고 있습니다.\n\n\n\n6. 기타 생활 신조와 가치관, 직장구성원으로서의 바람직한 태도, 대인관계 등에 대하여 기술하세요. \n\n[ 100자 이상 600자 이내]\n\n모두가 역지사지의 마음으로 \'책임 의식\'을 가진다면 그보다 더 좋은 팀은 없을 ...

# %%
# 해당 페이지 설정
browser = webdriver.Chrome(executable_path="C:\\chromedriver_win32\\chromedriver.exe")
browser.get("https://linkareer.com/cover-letter/15478?page=139&sort=PASSED_AT&tab=all")

# 상세 내용을 알수 있는 메서드
a = "/html/body/div[1]/div[1]/div[2]/div/div[2]/div[2]/div[1]/div/div[2]/div["
b = "]"

# 버튼의 xpath(버튼은 415까지 있음)
# button 2 3 4 5 6      >버튼)-> 7
d="/html/body/div[1]/div[1]/div[2]/div/div[2]/div[2]/div[1]/div/div[2]/div[21]/div/div[1]/button["
e="]"


# 데이터 프레임 정의 하기
WriteData_2 = pd.DataFrame()
WriteData_temp = pd.DataFrame()
WriteData_temp = WriteData_temp.append({"1" : "","2" : "", "3" : ""}, ignore_index = True)

one_idx = WriteData_temp.columns.get_loc("1")
two_idx = WriteData_temp.columns.get_loc("2")
three_idx = WriteData_temp.columns.get_loc("3")
page=1
while(page<29):
    page=page+1
    for k in range(3,8):
        f = d + str(k) + e
        browser.find_element_by_xpath(f).click()
        time.sleep(1)

        for l in range(1,21):
            c = a + str(l) + b
            browser.find_element_by_xpath(c).click()
            time.sleep(1)

            # 전체페이지를 가지고와서 전체데이터 확인
            res = browser.page_source # urllib.request.urlopen(~~)
            soup = bs(res, 'html.parser')
            WriteData_temp.iat[0,one_idx] = soup.find_all("p")[1].text
            WriteData_temp.iat[0,two_idx] = soup.find_all("p")[2].text
            WriteData_temp.iat[0,three_idx] = soup.find_all("p")[5].text

            WriteData_2 = WriteData_2.append(WriteData_temp, ignore_index=True)

            #   정보 비우기
            for j in range(0, len(WriteData_temp.columns)):
                WriteData_temp.iat[0,j] = ""


# WriteData 데이터 프레임 가져오기
WriteData_2
# Out:
#                                    1  \
# 0             삼성SDI / R&D / 2018 상반기
# 1            LG전자 / VC사업부 / 2018 상반기
# 2              삼성전자 / R&D / 2018 상반기
# 3            삼성바이오에피스 / - / 2018 상반기
# 4     CJ제일제당 / Food Sales / 2018 상반기
# ...                              ...
# 2795     LG CNS / 빅데이터 석박 / 2016 하반기
# 2796             KT / 부동산 / 2016 하반기
# 2797      SK텔레콤 / 소프트웨어개발 / 2016 하반기
# 2798          삼성전자 / 연구개발 / 2016 하반기
# 2799          KT / 유통채널관리 / 2016 하반기
#
#                                                       2  \
# 0                         부경대 / 전자공학 / 학점 3.79 / 토스 lv6
# 1                          고려대 / 전기전자 / 학점 4.3 / 토익 800
# 2                           인서울 / 전자 / 학점 4.01 / 토익 900
# 3                                      학점 4.17 / 토스 150
# 4
# ...                                                 ...
# 2795                       K대 대학원 / 통계 / 학점 4점대 / 토스 6급
# 2796                           수도권 중위권 / 건축공학 / 학점 3.61
# 2797  서울시립대학교 / 컴퓨터과학부 / 학점 3.34 / 토익 760, 오픽 IM1 / ...
# 2798       건동홍 / 신소재공학 / 학점 3.98 / 토익 815, 토스 140(Lv.6)
# 2799  지거국 / 중문/경제 / 학점 3.69 / 토익895, 토스lv.6, 신hsk6급 ...
#
#                                                       3
# 0     삼성SDI를 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십시오. (70...
# 1     <본인이 지원한 직무관련 지원동기와 역량에 대하여>\n\n[자동차 시스템 분야 최고...
# 2     Essay1\n삼성취업을 선택한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십...
# 3     1. 삼성바이오에피스를 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십시...
# 4     CJ제일제당과 해당 직무에지원한 동기는 무엇인가요? ①CJ제일제당이어야만 하는 이유...
# ...                                                 ...
# 2795  지원분야와 관련된 구체적인 지식이나 경험을 기재하여 주십시오. 글자수 487 / 1...
# 2796  1. 회사 및 해당직무에 지원하게 된 동기와 입사 후 회사에서 이루고 싶은 중장기적...
# 2797  1. 본인 및 본인의 성장 과정에 대해 기술하십시오. \n- 현재의 자신에게 가장 ...
# 2798  1. 삼성취업을 선택한 이유와 입사 후 회사에서 이루고 싶은 꿈을기술하십시오. (7...
# 2799  1. 회사 및 해당직무에 지원하게 된 동기와 입사 후 회사에서 이루고 싶은 중장기적...
#
# [2800 rows x 3 columns]

# %%
WriteData_2.to_csv('WriteData_2.csv',index=False,encoding="utf-8")

# %%
WriteData_2.head(50)
# Out:
#                                  1  \
# 0           삼성SDI / R&D / 2018 상반기
# 1          LG전자 / VC사업부 / 2018 상반기
# 2            삼성전자 / R&D / 2018 상반기
# 3          삼성바이오에피스 / - / 2018 상반기
# 4   CJ제일제당 / Food Sales / 2018 상반기
# 5           삼성전자 / DS부문 / 2018 상반기
# 6             현대카드 / SE / 2018 상반기
# 7            CJ제일제당 / - / 2018 상반기
# 8            삼성전자 / 메모리 / 2018 상반기
# 9            삼성전자 / SDI / 2018 상반기
# 10             포스코 / 사무 / 2018 상반기
# 11          CJ 오쇼핑 / MD / 2018 상반기
# 12      LG이노텍 / 기판소재사업부 / 2018 상반기
# 13        LG하우시스 / 국내영업 / 2018 상반기
# 14   CJ CGV / 멀티플렉스 매니저 / 2018 상반기
# 15           현대자동차 / SW / 2018 상반기
# 16       CJ제일제당 / 공무eng / 2018 상반기
# 17  삼성전자 / 메모리사업부 반도체개발 / 2018 상반기
# 18        LG전자 / R&D SW / 2018 상반기
# 19          한화 S&C / 법무 / 2018 상반기
# 20  CJ제일제당 / Food Sales / 2018 상반기
# 21              KT / 영업 / 2018 상반기
# 22          삼성전자 / DS부문 / 2018 상반기
# 23        CJ제일제당 / 생산기술 / 2018 상반기
# 24      삼성물산 리조트 / 해외영업 / 2018 상반기
# 25         현대오토에버 / ICT / 2018 상반기
# 26           현대제철 / R&D / 2018 상반기
# 27          LG 화학 / R&D / 2018 상반기
# 28        CJ올리브네트웍스 / - / 2018 상반기
# 29          SK하이닉스 / 영업 / 2018 상반기
# 30           LG전자 / R&D / 2018 상반기
# 31    LG전자 / H&A R&D_기구 / 2018 상반기
# 32          BGF리테일 / SC / 2018 상반기
# 33          현대모비스 / R&D / 2018 상반기
# 34           LG전자 / H&A / 2018 상반기
# 35          삼성화재 / 영업관리 / 2018 상반기
# 36          셀트리온 / 품질관리 / 2018 상반기
# 37         현대모비스 / 연구개발 / 2018 상반기
# 38        CJ제일제당 / 사료영업 / 2018 상반기
# 39        삼성전자 / DS 메모리 / 2018 상반기
# 40          삼성SDI / R&D / 2018 상반기
# 41         LG전자 / VC사업부 / 2018 상반기
# 42           삼성전자 / R&D / 2018 상반기
# 43         삼성바이오에피스 / - / 2018 상반기
# 44  CJ제일제당 / Food Sales / 2018 상반기
# 45          삼성전자 / DS부문 / 2018 상반기
# 46            현대카드 / SE / 2018 상반기
# 47           CJ제일제당 / - / 2018 상반기
# 48           삼성전자 / 메모리 / 2018 상반기
# 49           삼성전자 / SDI / 2018 상반기
#
#                                                     2  \
# 0                       부경대 / 전자공학 / 학점 3.79 / 토스 lv6
# 1                        고려대 / 전기전자 / 학점 4.3 / 토익 800
# 2                         인서울 / 전자 / 학점 4.01 / 토익 900
# 3                                    학점 4.17 / 토스 150
# 4
# 5                                   4년제 / 건축 / 학점 3.7
# 6                  서성한 / 컴퓨터공학과 / 학점 3.8 / 토익스피킹 레벨 6
# 7   서울사립대 / 어문계열, 상경계열 / 학점 3.6 / 토익800초반, 토익스피킹 레...
# 8     IST 중 1곳 / 신소재공학과 / 학점 4.14 / 토익스피킹 레벨6, 토익 920
# 9                         지거국 / 기계공학과 / 학점 3.8 / 토스 5
# 10                     해외대 / 경제학 / 학점 3.8 / 토익스피킹 레벨8
# 11                         연세대 / 의류환경학 / 학점 3.55 / 토익
# 12                     지거국 / 신소재공학부 / 학점 3.8 / 토익 840
# 13           서울 중상 / 건축공학 / 학점 3.90 / 토스 lv.6, 토익 825
# 14
# 15          서울 중상위 / 컴공 / 학점 4.x / 토익 900대, 토스 L6 / x
# 16     지거국 / 메카트로닉스 / 학점 4.13 / 오픽 IM2 / 인턴1회, 대외활동3회
# 17             성균관대학교 / 전자전기공학부 / 학점 3.7 / 토익스피킹 lv.6
# 18        서울 중상위권 / 컴퓨터공학과 / 학점 3.6 / 토익 960 / 단기인턴 1
# 19             서울 4년제 / 법학과 / 학점 3.7 / 토익 880 / 인턴 2회
# 20          건동홍 / 중어중문&국제통상 / 학점 4.01 / 토익 905, 오픽 AL
# 21                       지거국 / 사회계열 / 학점 3.5 / 토익 800
# 22
# 23                            서울 중하위 / 화학공학 / 학점 3.57
# 24  지방 사립 / 관광 / 학점 4.0 / 토익 865, 토스 lv6 / 해외 인턴, ...
# 25                                 인서울 / 전자과 / 학점 4.3
# 26                       중경외시 / 화학공학과 / 인턴1회, 대외활동 3회
# 27                             GIST / 기전공학부 / 학점 3.54
# 28     정보보호학과 / 학점 3.0 / 토익 800 / 공모전 수상경력 1회, 동아리 활동
# 29                       서성한 / 학점 3.5 / 오픽 AL / 인턴 2회
# 30                    지방 4년제 / 전자공학과 / 학점 4.0 / 오픽 IH
# 31  지거국 / 기계과(기계설계 복수전공) / 학점 3.95/4.5 / 토익 740 / ...
# 32  서울 중하위권 / 상경 / 학점 3.88 / 토익 885점, 토스 LV.6 / 단기...
# 33           지거국 / 컴퓨터공학 / 학점 3.7 / 토익850 , 토익스피킹 레벨6
# 34                    지방4년제 / 전자전기 / 학점 3.79 / 토스 레벨6
# 35  지방 국립4년제 / 관광 / 학점 3.88 / 토익 865 / 대외활동 4회, 봉사...
# 36                  인서울 / 생명과학 / 학점 3.25/4.3 / 토익 935
# 37                     지방 4년제 / 전자공학 / 학점 4.0 / 오픽 IH
# 38  강원대학교 / 학점 3.7 / 토익 765 / 인턴1회, 대외활동 1회, 공모전1회...
# 39                    전자공학과 / 학점 3점 초중 / 오픽 IH,토익 795
# 40                      부경대 / 전자공학 / 학점 3.79 / 토스 lv6
# 41                       고려대 / 전기전자 / 학점 4.3 / 토익 800
# 42                        인서울 / 전자 / 학점 4.01 / 토익 900
# 43                                   학점 4.17 / 토스 150
# 44
# 45                                  4년제 / 건축 / 학점 3.7
# 46                 서성한 / 컴퓨터공학과 / 학점 3.8 / 토익스피킹 레벨 6
# 47  서울사립대 / 어문계열, 상경계열 / 학점 3.6 / 토익800초반, 토익스피킹 레...
# 48    IST 중 1곳 / 신소재공학과 / 학점 4.14 / 토익스피킹 레벨6, 토익 920
# 49                        지거국 / 기계공학과 / 학점 3.8 / 토스 5
#
#                                                     3
# 0   삼성SDI를 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십시오. (70...
# 1   <본인이 지원한 직무관련 지원동기와 역량에 대하여>\n\n[자동차 시스템 분야 최고...
# 2   Essay1\n삼성취업을 선택한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십...
# 3   1. 삼성바이오에피스를 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십시...
# 4   CJ제일제당과 해당 직무에지원한 동기는 무엇인가요? ①CJ제일제당이어야만 하는 이유...
# 5   1. 삼성전자를 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십시오. (...
# 6   1. 본인의Digital 역량 및 관심도에 대해 자유롭게 기술하시오. \n[전공 지...
# 7   본인의 목표를 달성하기 위해 상대방을 설득시켰던 경험을 바탕으로 아래 질문을 작성해...
# 8   1. 삼성전자를 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십시오.\n...
# 9   삼성SDI를 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십시오.\n\n...
# 10  [포스코 건설의 해외 투자 확대]\n\n제가 회사를 선택하는 기준은 제 모든 역량을...
# 11  대학생활과 졸업이후를 포함하여, 아래 나열한 경험중에 본인이 가장 유사하게 활동한 ...
# 12  LG이노텍과 지원분야를 선택하신 이유\n\n미래를 주도하는 전자제품에 관하여 글로써...
# 13  My Career Goal\n10년 후 LG하우시스의 구성원으로서 본인의 목표와 비...
# 14  01. CJ CGV와 해당 직무에 지원한 동기는 무엇인가요? ① CJ CGV와 지원...
# 15  1. 본인이 회사를 선택할 때의 기준은 무엇이며, 왜 현대자동차가 그 기준에 적합한...
# 16  1. CJ제일제당과 해당 직무에 지원한 동기는 무엇인가요?\n\nCJ제일제당은 Fa...
# 17  삼성 취업을 선택한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십시오.-696...
# 18  My Future] 본인이 지원한 직무관련 향후 계획에 대하여\n\nGuide> 본...
# 19  협업을 통해 좋은 성과를 달성했던 사례와, 실패했던 사례를 한가지씩 말씀해주십시오....
# 20  1.    CJ제일제당과 해당 직무에 지원한 동기는 무엇인가요?\n\n① CJ제일제...
# 21  공동의 목표 달성을 위한 협업 경험을 본인이 수행한역할 중심으로 제시하고, 해당 경...
# 22  3. 최근 사회이슈 중 중요하다고 생각되는 한 가지를 선택하고 이에 관한 자신의 견...
# 23  ① CJ제일제당이어야만 하는 이유\n\n[뚝심으로 만들어진 CJ제일제당]\n\nCJ...
# 24  본인의 성장과정을 간략히 기술하되 현재의 자신에게 가장 큰 영향을 끼친 사건, 인물...
# 25  본인이 도전했던 여러 경험 중 가장 힘들었던 경험을 작성하고 이를 통해 배운 점은 ...
# 26  1. 본인 성격의 장단점을 자신의 성장과정과 경험을 기반으로 서술하여 주십시오. (...
# 27  My Story\n자신의 성장과정 및 개인 특성, 장점을 중심으로 기술하여 주시기 ...
# 28  여러분이 선택한 직무에 지원한 동기는 무엇인가요? ① 회사(올리브네트웍스 IT사업부...
# 29  자발적으로 최고 수준의 목표를 세우고 끈질기게 성취한 경험에 대해 서술해 주십시오\...
# 30  1. 1.본인이 지원한 직무관련 지원동기와 역량에 대하여(1000)\n[H/W와 S...
# 31  1.본인이 지원한 직무관련 지원동기와 역량에 대하여\n가전제품은 LG라는 말, 이제...
# 32  2. 공동의 목표를 달성하기 위하여 가장 중요하다고 생각하는 역량 1가지를 선정하고...
# 33  1. 본인의 지원직무를 어떻게 이해하고 있는지 구체적으로 기술하고, 해당 분야에 본...
# 34  본인이 지원한 직무관련 지원동기와 역량에 대하여\n\n저는 전자전기공학부를 다니면서...
# 35  Essay 3최근 사회이슈 중 중요하다고 생각되는 한가지를 선택하고 이에 관한 자신...
# 36  [자유기술]\n\n제가 셀트리온의 화학면역QC로서 가지고 있는 자질은 다음과 같습니...
# 37  1.본인의 지원직무를 어떻게 이해하고 있는지 구체적으로 기술하고, 해당 분야에 본인...
# 38  CJ제일제당과 해당 직무에 지원한 동기는 무엇인가요? ① CJ제일제당이어야만 하는 ...
# 39  Essay 1\n\n삼성전자를 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기...
# 40  삼성SDI를 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십시오. (70...
# 41  <본인이 지원한 직무관련 지원동기와 역량에 대하여>\n\n[자동차 시스템 분야 최고...
# 42  Essay1\n삼성취업을 선택한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십...
# 43  1. 삼성바이오에피스를 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십시...
# 44  CJ제일제당과 해당 직무에지원한 동기는 무엇인가요? ①CJ제일제당이어야만 하는 이유...
# 45  1. 삼성전자를 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십시오. (...
# 46  1. 본인의Digital 역량 및 관심도에 대해 자유롭게 기술하시오. \n[전공 지...
# 47  본인의 목표를 달성하기 위해 상대방을 설득시켰던 경험을 바탕으로 아래 질문을 작성해...
# 48  1. 삼성전자를 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십시오.\n...
# 49  삼성SDI를 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십시오.\n\n...

# %%
import pandas as pd
path="WriteDate.csv"
df= pd.read_csv(path)
df.head()
# Out:
#                                     1  \
# 0              한국석유공사 / 설비 / 2020 상반기
# 1      CJ제일제당 / Food Sales / 2020 상반기
# 2  한국가스안전공사 / LP가스 안전지킴이사업 / 2020 상반기
# 3               코레일 / 사무영업 / 2020 상반기
# 4           한국기술교육대학교 / 행정 / 2020 상반기
#
#                                                    2  \
# 0  광주전자공업고등학교 / 학점 1.7등급 / 인천 글로벌 숙련 진흥원 5일, 선반, ...
# 1  중경외시 / 상경계열 / 학점 3.92 / 토익 905, 토스 LV 6 / 봉사활동...
# 2          제주대학교 / 학점 3.3 / 토익830 / 컴퓨터활용능력1급, 한국사1급
# 3   충남대학교 / 학점 3.87 / 토익 835 / 토론동아리 3년, 컴활1급, 한국사1급
# 4             건국대학교 / 학점 4.0 / 토익 780 / 컴활 1급, 한국사1급
#
#                                                    3
# 0  7.한국석유공사\n\n 1. 지원 분야 직무기술서 ‘직무수행 내용’ 중 본인이 가장...
# 1  CJ제일제당 및 선택한 직무에 대한 지원동기는 무엇인가요? ① 선택한 직무에 관심을...
# 2  \n1. 한국가스안전공사가 진행하는 사업에 관심을 갖고 공사에 지원한 동기에 대해 ...
# 3  1.공동체의 일원으로서 가장 중요하게 생각하는 가치를 제시하고, 그 가치를 실천했던...
# 4  1. 본인이 가진 가장 뛰어난 점과 그렇게 판단한 이유, 고용노동연수원 업무수행에서...

# %%
df2 =df['1'].str.split("/",expand=True)
df2
# Out:
#                 0               1          2     3     4
# 0         한국석유공사              설비    2020 상반기  None  None
# 1         CJ제일제당      Food Sales    2020 상반기  None  None
# 2       한국가스안전공사    LP가스 안전지킴이사업    2020 상반기  None  None
# 3            코레일            사무영업    2020 상반기  None  None
# 4      한국기술교육대학교              행정    2020 상반기  None  None
# ...           ...             ...        ...   ...   ...
# 10102      현대자동차            영업관리    2013 상반기  None  None
# 10103         심팩            용접관리    2013 상반기  None  None
# 10104       한국전력        인턴[송,배전]    2013 상반기  None  None
# 10105       한국전력        인턴[송,배전]    2013 상반기  None  None
# 10106       한국전력        인턴[송,배전]    2013 상반기  None  None
#
# [10107 rows x 5 columns]

# %%
df2.rename(columns={0:"지원회사명"})
df2
# Out:
#                 0               1          2     3     4
# 0         한국석유공사              설비    2020 상반기  None  None
# 1         CJ제일제당      Food Sales    2020 상반기  None  None
# 2       한국가스안전공사    LP가스 안전지킴이사업    2020 상반기  None  None
# 3            코레일            사무영업    2020 상반기  None  None
# 4      한국기술교육대학교              행정    2020 상반기  None  None
# ...           ...             ...        ...   ...   ...
# 10102      현대자동차            영업관리    2013 상반기  None  None
# 10103         심팩            용접관리    2013 상반기  None  None
# 10104       한국전력        인턴[송,배전]    2013 상반기  None  None
# 10105       한국전력        인턴[송,배전]    2013 상반기  None  None
# 10106       한국전력        인턴[송,배전]    2013 상반기  None  None
#
# [10107 rows x 5 columns]
